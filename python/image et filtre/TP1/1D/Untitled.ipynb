# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('imagesCercles.tif')

plt.imshow(img)

print(img.shape)
# Out:
# (512, 512)

# %%
(lignes,colonnes)= img.shape

img_sampled_4 = img[1:lignes:4,1:colonnes:4]
plt.imshow(img_sampled_4)
